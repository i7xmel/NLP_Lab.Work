# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize, TweetTokenizer, RegexpTokenizer
from nltk.tokenize import TreebankWordTokenizer, MWETokenizer
from textblob import TextBlob
import spacy
from gensim.utils import tokenize as gensim_tokenize
from keras.preprocessing.text import text_to_word_sequence
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Sample text

# %%
text = "Tokenization is a crucial step in natural language processing, don't you agree? 😊 Let's explore different tokenization techniques!"

# %% [markdown]
# # a. Word Tokenization

# %%
word_tokens = word_tokenize(text)
print("Word Tokenization:", word_tokens)
# Out:
# Word Tokenization: ['Tokenization', 'is', 'a', 'crucial', 'step', 'in', 'natural', 'language', 'processing', ',', 'do', "n't", 'you', 'agree', '?', '😊', 'Let', "'s", 'explore', 'different', 'tokenization', 'techniques', '!']

# %% [markdown]
# # b. Sentence Tokenization

# %%
sent_tokens = sent_tokenize(text)
print("Sentence Tokenization:", sent_tokens)
# Out:
# Sentence Tokenization: ["Tokenization is a crucial step in natural language processing, don't you agree?", "😊 Let's explore different tokenization techniques!"]

# %% [markdown]
# # c. Punctuation-based Tokenizer

# %%
punctuation_tokenizer = RegexpTokenizer(r'\w+')
punctuation_tokens = punctuation_tokenizer.tokenize(text)
print("Punctuation-based Tokenizer:", punctuation_tokens)
# Out:
# Punctuation-based Tokenizer: ['Tokenization', 'is', 'a', 'crucial', 'step', 'in', 'natural', 'language', 'processing', 'don', 't', 'you', 'agree', 'Let', 's', 'explore', 'different', 'tokenization', 'techniques']

# %% [markdown]
# # d. Treebank Word tokenizer

# %%
treebank_tokenizer = TreebankWordTokenizer()
treebank_tokens = treebank_tokenizer.tokenize(text)
print("Treebank Word tokenizer:", treebank_tokens)
# Out:
# Treebank Word tokenizer: ['Tokenization', 'is', 'a', 'crucial', 'step', 'in', 'natural', 'language', 'processing', ',', 'do', "n't", 'you', 'agree', '?', '😊', 'Let', "'s", 'explore', 'different', 'tokenization', 'techniques', '!']

# %% [markdown]
# # e. Tweet Tokenizer

# %%
tweet_tokenizer = TweetTokenizer()
tweet_tokens = tweet_tokenizer.tokenize(text)
print("Tweet Tokenizer:", tweet_tokens)
# Out:
# Tweet Tokenizer: ['Tokenization', 'is', 'a', 'crucial', 'step', 'in', 'natural', 'language', 'processing', ',', "don't", 'you', 'agree', '?', '😊', "Let's", 'explore', 'different', 'tokenization', 'techniques', '!']

# %% [markdown]
# # f. Multi-Word Expression Tokenizer

# %%
multi_word_tokenizer = MWETokenizer()
multi_word_tokens = multi_word_tokenizer.tokenize(text.split())
print("Multi-Word Expression Tokenizer:", multi_word_tokens)
# Out:
# Multi-Word Expression Tokenizer: ['Tokenization', 'is', 'a', 'crucial', 'step', 'in', 'natural', 'language', 'processing,', "don't", 'you', 'agree?', '😊', "Let's", 'explore', 'different', 'tokenization', 'techniques!']

# %% [markdown]
# # g. TextBlob Word Tokenize

# %%
textblob_tokens = TextBlob(text).words
print("TextBlob Word Tokenize:", textblob_tokens)
# Out:
# TextBlob Word Tokenize: ['Tokenization', 'is', 'a', 'crucial', 'step', 'in', 'natural', 'language', 'processing', 'do', "n't", 'you', 'agree', '😊', 'Let', "'s", 'explore', 'different', 'tokenization', 'techniques']

# %% [markdown]
# # h. spaCy Tokenizer

# %%
nlp = spacy.load('en_core_web_sm')
spacy_doc = nlp(text)
spacy_tokens = [token.text for token in spacy_doc]
print("spaCy Tokenizer:", spacy_tokens)
# Out:
# spaCy Tokenizer: ['Tokenization', 'is', 'a', 'crucial', 'step', 'in', 'natural', 'language', 'processing', ',', 'do', "n't", 'you', 'agree', '?', '😊', 'Let', "'s", 'explore', 'different', 'tokenization', 'techniques', '!']

# %% [markdown]
# # i. Gensim word tokenizer

# %%
gensim_tokens = list(gensim_tokenize(text))
print("Gensim word tokenizer:", gensim_tokens)
# Out:
# Gensim word tokenizer: ['Tokenization', 'is', 'a', 'crucial', 'step', 'in', 'natural', 'language', 'processing', 'don', 't', 'you', 'agree', 'Let', 's', 'explore', 'different', 'tokenization', 'techniques']

# %% [markdown]
# # j. Tokenization with Keras

# %%
keras_tokens = text_to_word_sequence(text)
print("Tokenization with Keras:", keras_tokens)
# Out:
# Tokenization with Keras: ['tokenization', 'is', 'a', 'crucial', 'step', 'in', 'natural', 'language', 'processing', "don't", 'you', 'agree', '😊', "let's", 'explore', 'different', 'tokenization', 'techniques']
