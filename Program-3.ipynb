# %% [markdown]
# # Malayalam Sentence Tokenization

# %%
pip install indic-nlp-library

# %%
import nltk
nltk.download('indic_nltk')
from indicnlp.tokenize import indic_tokenize
# Out:
# [nltk_data] Error loading indic_nltk: Package 'indic_nltk' not found
# [nltk_data]     in index

# %%
# Sample Malayalam text
malayalam_text = "സ്വേച്‌ഛാധിപത്യത്തിനും ചൂഷണത്തിനും അടിച്ചമർത്തലിനുമെതിരായ ഇന്ത്യൻ കമ്മ്യൂണിസ്റ്റ് പ്രസ്ഥാനത്തിന്റെ ധീരമായ പോരാട്ടങ്ങൾക്ക് 2020 ഒക്ടോബർ 17-ന് നൂറു വയസ്സു തികഞ്ഞു.സമത്വത്തിലും ജനാധിപത്യത്തിലും അധിഷ്‌ഠിതമായ ഒരു സമൂഹം കെട്ടിപ്പടുക്കാൻ സ്വന്തം ജീവിതം ഉഴിഞ്ഞുവച്ച ലക്ഷക്കണക്കിനു വിപ്ലവകാരികളുടെ ത്യാഗങ്ങളുടെ ഒരു നൂറ്റാണ്ടാണ് കടന്നുപോയിരിക്കുന്നത്. ആയിരക്കണക്കിന് കമ്മ്യൂണിസ്റ്റ് പ്രവർത്തകർ ഈ പാതയിൽ രക്തസാക്ഷിത്വം വരിച്ചു. അതിലുമേറെ പേർ ഭരണകൂട അടിച്ചമർത്തലുകളെയും, ആക്രമണങ്ങളെയും, വിധ്വംസക ശ്രമങ്ങളെയും എതിരിട്ടുകൊണ്ട് പുതുസമൂഹ സൃഷ്‌ടിക്കായുള്ള പോരാട്ടങ്ങൾ തുടരുന്നു"

# %%
# Tokenize Malayalam text
malayalam_tokens = indic_tokenize.trivial_tokenize(malayalam_text)

print("Malayalam Tokens:", malayalam_tokens)
# Out:
# Malayalam Tokens: ['സ്വേച്\u200cഛാധിപത്യത്തിനും', 'ചൂഷണത്തിനും', 'അടിച്ചമർത്തലിനുമെതിരായ', 'ഇന്ത്യൻ', 'കമ്മ്യൂണിസ്റ്റ്', 'പ്രസ്ഥാനത്തിന്റെ', 'ധീരമായ', 'പോരാട്ടങ്ങൾക്ക്', '2020', 'ഒക്ടോബർ', '17', '-', 'ന്', 'നൂറു', 'വയസ്സു', 'തികഞ്ഞു', '.', 'സമത്വത്തിലും', 'ജനാധിപത്യത്തിലും', 'അധിഷ്\u200cഠിതമായ', 'ഒരു', 'സമൂഹം', 'കെട്ടിപ്പടുക്കാൻ', 'സ്വന്തം', 'ജീവിതം', 'ഉഴിഞ്ഞുവച്ച', 'ലക്ഷക്കണക്കിനു', 'വിപ്ലവകാരികളുടെ', 'ത്യാഗങ്ങളുടെ', 'ഒരു', 'നൂറ്റാണ്ടാണ്', 'കടന്നുപോയിരിക്കുന്നത്', '.', 'ആയിരക്കണക്കിന്', 'കമ്മ്യൂണിസ്റ്റ്', 'പ്രവർത്തകർ', 'ഈ', 'പാതയിൽ', 'രക്തസാക്ഷിത്വം', 'വരിച്ചു', '.', 'അതിലുമേറെ', 'പേർ', 'ഭരണകൂട', 'അടിച്ചമർത്തലുകളെയും', ',', 'ആക്രമണങ്ങളെയും', ',', 'വിധ്വംസക', 'ശ്രമങ്ങളെയും', 'എതിരിട്ടുകൊണ്ട്', 'പുതുസമൂഹ', 'സൃഷ്\u200cടിക്കായുള്ള', 'പോരാട്ടങ്ങൾ', 'തുടരുന്നു']

# %% [markdown]
# #Arabic Sentence Tokenization

# %%
pip install nltk pyarabic
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize

# %%
# Sample Arabic text
arabic_text = "بدأت أولى الهجرات البشرية الهامة إلى فلسطين في بداية الألف الثالثة قبل الميلاد، وهي هجرة الكنعانيين الذين عرفوا باسم الأماكن التي نزلوا فيها، وبعد فترة أصبحت هناك ثلاث لغات: الكنعانية والآرامية -لغة المسيح عليه السلام- والعربية، وظلت فلسطين تسمى أرض كنعان حتى عام 1200 ق.م حينما غزتها القبائل الكريتية"

# %%
# Tokenize Arabic text using NLTK
arabic_tokens_nltk = word_tokenize(arabic_text)

print("Arabic Tokens (NLTK):", arabic_tokens_nltk)
# Out:
# Arabic Tokens (NLTK): ['بدأت', 'أولى', 'الهجرات', 'البشرية', 'الهامة', 'إلى', 'فلسطين', 'في', 'بداية', 'الألف', 'الثالثة', 'قبل', 'الميلاد،', 'وهي', 'هجرة', 'الكنعانيين', 'الذين', 'عرفوا', 'باسم', 'الأماكن', 'التي', 'نزلوا', 'فيها،', 'وبعد', 'فترة', 'أصبحت', 'هناك', 'ثلاث', 'لغات', ':', 'الكنعانية', 'والآرامية', '-لغة', 'المسيح', 'عليه', 'السلام-', 'والعربية،', 'وظلت', 'فلسطين', 'تسمى', 'أرض', 'كنعان', 'حتى', 'عام', '1200', 'ق.م', 'حينما', 'غزتها', 'القبائل', 'الكريتية']

# %%
#Alternatively, using PyArabic library
from pyarabic.araby import tokenize

arabic_tokens_pyarabic = tokenize(arabic_text)

print("Arabic Tokens (PyArabic):", arabic_tokens_pyarabic)
# Out:
# Arabic Tokens (PyArabic): ['بدأت', 'أولى', 'الهجرات', 'البشرية', 'الهامة', 'إلى', 'فلسطين', 'في', 'بداية', 'الألف', 'الثالثة', 'قبل', 'الميلاد', '،', 'وهي', 'هجرة', 'الكنعانيين', 'الذين', 'عرفوا', 'باسم', 'الأماكن', 'التي', 'نزلوا', 'فيها', '،', 'وبعد', 'فترة', 'أصبحت', 'هناك', 'ثلاث', 'لغات', ':', 'الكنعانية', 'والآرامية', '-', 'لغة', 'المسيح', 'عليه', 'السلام', '-', 'والعربية', '،', 'وظلت', 'فلسطين', 'تسمى', 'أرض', 'كنعان', 'حتى', 'عام', '1200', 'ق', '.', 'م', 'حينما', 'غزتها', 'القبائل', 'الكريتية']
